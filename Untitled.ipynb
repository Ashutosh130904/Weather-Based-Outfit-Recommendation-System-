# %%
import numpy as np
import pandas as pd
from collections import Counter

# %%
df = pd.read_csv("weather_outfit_dataset_final.csv")

# %%
df.tail(20)
# Out:
#       Temperature  Humidity  WindSpeed Weather  TimeOfDay LocationType  \
# 1480           21        77         19   Windy  Afternoon        Urban
# 1481           14        44         32  Cloudy  Afternoon        Rural
# 1482            5        90         14   Rainy      Night      Coastal
# 1483           26        97         11   Windy  Afternoon        Urban
# 1484           30        74         39   Rainy    Morning        Urban
# 1485           22        17         19   Rainy      Night        Urban
# 1486           18        54         29   Rainy      Night        Urban
# 1487           33        96         37   Sunny      Night      Coastal
# 1488           16        56          2   Windy      Night        Rural
# 1489           40        49         27   Sunny  Afternoon      Coastal
# 1490           39        85         25   Windy  Afternoon        Rural
# 1491           16        63         29  Cloudy    Morning      Coastal
# 1492           11        85         12  Cloudy    Evening        Urban
# 1493           33        55         12  Cloudy    Evening        Urban
# 1494           15        56          1   Windy    Morning      Coastal
# 1495           37        24         36   Rainy    Evening      Coastal
# 1496           10        28         37   Rainy    Morning        Rural
# 1497           19        35          1   Sunny  Afternoon      Coastal
# 1498           36        61         35   Sunny      Night      Coastal
# 1499           15        31         25  Cloudy      Night        Rural
#
#       Gender AgeGroup        Outfit
# 1480    Male     Teen         Scarf
# 1481  Female    Child       Sweater
# 1482  Female    Child       Sweater
# 1483  Female    Adult         Boots
# 1484  Female     Teen      Raincoat
# 1485  Female   Senior      Raincoat
# 1486    Male   Senior      Raincoat
# 1487    Male    Child         Kurta
# 1488    Male    Child        Hoodie
# 1489  Female     Teen  Summer Dress
# 1490    Male    Child           Cap
# 1491  Female   Senior   Salwar Suit
# 1492  Female    Adult   Winter Coat
# 1493    Male    Adult         Kurta
# 1494    Male     Teen    Sweatshirt
# 1495  Female    Adult      Raincoat
# 1496    Male    Child          Coat
# 1497  Female    Child   Salwar Suit
# 1498    Male    Child       T-shirt
# 1499    Male    Child         Kurta

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Temperature   1500 non-null   int64
#  1   Humidity      1500 non-null   int64
#  2   WindSpeed     1500 non-null   int64
#  3   Weather       1500 non-null   object
#  4   TimeOfDay     1500 non-null   object
#  5   LocationType  1500 non-null   object
#  6   Gender        1500 non-null   object
#  7   AgeGroup      1500 non-null   object
#  8   Outfit        1500 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 105.6+ KB

# %%
df.describe()
# Out:
#        Temperature     Humidity    WindSpeed
# count  1500.000000  1500.000000  1500.000000
# mean     25.108667    53.344667    19.558667
# std      11.681774    26.258412    11.521533
# min       5.000000    10.000000     0.000000
# 25%      15.000000    30.000000    10.000000
# 50%      26.000000    53.000000    20.000000
# 75%      35.250000    77.000000    29.000000
# max      44.000000    99.000000    39.000000

# %%
print(df.isnull().sum())
# Out:
# Temperature     0
# Humidity        0
# WindSpeed       0
# Weather         0
# TimeOfDay       0
# LocationType    0
# Gender          0
# AgeGroup        0
# Outfit          0
# dtype: int64

# %%
df['Outfit'].value_counts()
# Out:
# Outfit
# Raincoat               287
# Sweater                 99
# Shirt with Jeans        82
# T-shirt                 80
# Jacket                  64
# Kurti with Leggings     63
# Top with Jeans          63
# Salwar Suit             61
# Coat                    58
# Cap                     52
# Kurta                   51
# Windbreaker             48
# Winter Coat             43
# Woolen Kurti            38
# Summer Dress            34
# Vest                    32
# Jeans                   30
# Shorts                  28
# Kurti                   27
# Windcheater             26
# Sleeveless Top          25
# Sweatshirt              23
# Scarf                   19
# Hoodie                  18
# Full-sleeve Shirt       16
# Comfort Fit Pants       14
# Cardigan                14
# Stole                   13
# Leggings                13
# Track Pants             13
# Shawl                   12
# Sneakers                12
# Full-length Dress       11
# Long Skirt              11
# Trousers                11
# Boots                    9
# Name: count, dtype: int64

# %%
df['Weather'].value_counts()
# Out:
# Weather
# Rainy     414
# Cloudy    379
# Sunny     357
# Winter    350
# Name: count, dtype: int64

# %%
df['TimeOfDay'].value_counts()
# Out:
# TimeOfDay
# Evening    395
# Morning    388
# Day        381
# Night      336
# Name: count, dtype: int64

# %%
df['LocationType'].value_counts()
# Out:
# LocationType
# Urban      524
# Coastal    504
# Rural      472
# Name: count, dtype: int64

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns
# from scipy.stats import skew, kurtosis

# # ========== 1. Correlation Heatmap ==========
# plt.figure(figsize=(10, 6))
# sns.heatmap(df[numerical_cols + categorical_cols].corr(), annot=True, cmap='coolwarm', fmt=".2f")
# plt.title("Correlation Heatmap")
# plt.tight_layout()
# plt.show()

# # ========== 2. Boxplots for Outlier Detection ==========
# for col in numerical_cols:
#     plt.figure(figsize=(6, 4))
#     sns.boxplot(y=df[col], color='skyblue')
#     plt.title(f'Boxplot of {col}')
#     plt.tight_layout()
#     plt.show()

# # ========== 3. Histograms with Skewness and Kurtosis ==========
# for col in numerical_cols:
#     plt.figure(figsize=(6, 4))
#     sns.histplot(df[col], kde=True, color='salmon', bins=30)
#     plt.title(f'{col} Distribution\nSkewness: {df[col].skew():.2f} | Kurtosis: {df[col].kurtosis():.2f}')
#     plt.xlabel(col)
#     plt.ylabel("Frequency")
#     plt.tight_layout()
#     plt.show()

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder

# %%
le = LabelEncoder()
oe = OrdinalEncoder()

# %%
print(df['Outfit'])
# Out:
# 0            Sweater
# 1        Light Dress
# 2              Dress
# 3             Hoodie
# 4            Sweater
#             ...
# 1495    Light Jacket
# 1496    Cotton Dress
# 1497          Shorts
# 1498     Windbreaker
# 1499          Hoodie
# Name: Outfit, Length: 1500, dtype: object

# %%
df['Outfit'] = df['Outfit'].astype(str)
df['Outfit'] = le.fit_transform(df['Outfit'])

# %%
print(df['Outfit'])
# Out:
# 0       11
# 1        4
# 2        1
# 3        2
# 4       11
#         ..
# 1495     5
# 1496     0
# 1497    10
# 1498    15
# 1499     2
# Name: Outfit, Length: 1500, dtype: int64

# %%
df[['Weather']] = df[['Weather']].astype(str)
df[['Weather']] = oe.fit_transform(df[['Weather']])

# %%
print(df['Weather'].unique())
# Out:
# [3. 1. 2. 0.]

# %%
df[['TimeOfDay']] = df[['TimeOfDay']].astype(str)
df[['TimeOfDay']] = oe.fit_transform(df[['TimeOfDay']])

# %%
print(df['TimeOfDay'])
# Out:
# 0       1.0
# 1       0.0
# 2       0.0
# 3       2.0
# 4       2.0
#        ...
# 1495    2.0
# 1496    0.0
# 1497    0.0
# 1498    3.0
# 1499    3.0
# Name: TimeOfDay, Length: 1500, dtype: float64

# %%
df[['LocationType']] = df[['LocationType']].astype(str)
df[['LocationType']] = oe.fit_transform(df[['LocationType']])

# %%
print(df['LocationType'])
# Out:
# 0       2.0
# 1       1.0
# 2       1.0
# 3       2.0
# 4       2.0
#        ...
# 1495    2.0
# 1496    0.0
# 1497    0.0
# 1498    2.0
# 1499    0.0
# Name: LocationType, Length: 1500, dtype: float64

# %%
df[['Gender']] = df[['Gender']].astype(str)
df[['Gender']] = oe.fit_transform(df[['Gender']])

# %%
print(df['Gender'])
# Out:
# 0       0.0
# 1       1.0
# 2       0.0
# 3       1.0
# 4       1.0
#        ...
# 1495    0.0
# 1496    0.0
# 1497    1.0
# 1498    1.0
# 1499    1.0
# Name: Gender, Length: 1500, dtype: float64

# %%
df[['AgeGroup']] = df[['AgeGroup']].astype(str)
df[['AgeGroup']] = oe.fit_transform(df[['AgeGroup']])

# %%
print(df['AgeGroup'])
# Out:
# 0       0.0
# 1       2.0
# 2       3.0
# 3       2.0
# 4       0.0
#        ...
# 1495    2.0
# 1496    0.0
# 1497    2.0
# 1498    3.0
# 1499    2.0
# Name: AgeGroup, Length: 1500, dtype: float64

# %%
df.head(20)
# Out:
#     Temperature  Humidity  Weather  WindSpeed  TimeOfDay  LocationType  \
# 0            11        26      3.0         19        1.0           2.0
# 1            40        58      1.0         20        0.0           1.0
# 2            19        21      3.0         21        0.0           1.0
# 3            10        21      2.0         31        2.0           2.0
# 4            12        96      2.0         19        2.0           2.0
# 5            28        72      3.0         33        1.0           2.0
# 6            33        92      2.0         17        0.0           2.0
# 7            12        29      1.0         17        3.0           1.0
# 8            42       100      0.0         13        3.0           2.0
# 9            11        33      1.0         16        0.0           2.0
# 10            7        73      3.0          0        2.0           2.0
# 11           14        56      2.0         14        2.0           0.0
# 12           38        60      2.0          5        0.0           2.0
# 13           40        72      1.0         28        0.0           2.0
# 14           32        89      2.0         31        1.0           2.0
# 15            9        46      1.0         30        3.0           0.0
# 16           34        65      1.0         20        3.0           1.0
# 17           35        71      2.0          7        0.0           1.0
# 18           44        58      2.0         28        0.0           0.0
# 19           24        78      1.0         19        2.0           0.0
#
#     Outfit  Gender  AgeGroup
# 0       11     0.0       0.0
# 1        4     1.0       2.0
# 2        1     0.0       3.0
# 3        2     1.0       2.0
# 4       11     1.0       0.0
# 5        1     1.0       1.0
# 6        0     1.0       0.0
# 7       11     0.0       3.0
# 8        6     1.0       2.0
# 9        5     1.0       2.0
# 10      11     1.0       3.0
# 11      11     0.0       1.0
# 12      10     1.0       2.0
# 13       6     1.0       1.0
# 14       0     1.0       3.0
# 15       2     0.0       0.0
# 16      13     0.0       1.0
# 17       0     0.0       1.0
# 18       4     0.0       1.0
# 19       8     1.0       2.0

# %%
features = ["Temperature", "Humidity", "Weather", "WindSpeed", "TimeOfDay", "LocationType", "Gender", "AgeGroup"]

# %%
X = df[features].values
y = df['Outfit'].values

# %%
from imblearn.over_sampling import SMOTE

# %%
from collections import Counter
from imblearn.over_sampling import SMOTE
import pandas as pd

print("Before SMOTE:", Counter(y))

# Convert y to pandas Series for isin()
y_series = pd.Series(y)

min_samples_required = 3
class_counts = Counter(y)
valid_classes = [cls for cls, count in class_counts.items() if count >= min_samples_required]

mask = y_series.isin(valid_classes)
X_filtered, y_filtered = X[mask], y[mask]

# Apply SMOTE
sm = SMOTE(random_state=42, k_neighbors=1)
X_res, y_res = sm.fit_resample(X_filtered, y_filtered)

print("After SMOTE:", Counter(y_res))
# Out:
# Before SMOTE: Counter({np.int64(10): 201, np.int64(5): 173, np.int64(11): 148, np.int64(4): 136, np.int64(13): 135, np.int64(9): 119, np.int64(1): 106, np.int64(3): 105, np.int64(0): 77, np.int64(2): 70, np.int64(6): 68, np.int64(7): 46, np.int64(8): 45, np.int64(15): 42, np.int64(16): 15, np.int64(14): 8, np.int64(12): 6})
# After SMOTE: Counter({np.int64(11): 201, np.int64(4): 201, np.int64(1): 201, np.int64(2): 201, np.int64(0): 201, np.int64(6): 201, np.int64(5): 201, np.int64(10): 201, np.int64(13): 201, np.int64(8): 201, np.int64(14): 201, np.int64(15): 201, np.int64(3): 201, np.int64(9): 201, np.int64(12): 201, np.int64(7): 201, np.int64(16): 201})

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X_res, y_res, test_size=0.2, random_state=42, stratify=y_res
)

# %%
X_train
# Out:
# array([[5.00000000e+00, 2.94558396e+01, 2.48527987e+00, ...,
#         1.48527987e+00, 5.14720126e-01, 2.02944025e+00],
#        [3.30000000e+01, 5.30000000e+01, 2.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00],
#        [8.35397001e+00, 9.71769850e+01, 9.11507498e-01, ...,
#         8.84925021e-02, 1.00000000e+00, 2.00000000e+00],
#        ...,
#        [2.19947258e+01, 7.45079113e+01, 1.00000000e+00, ...,
#         9.94725814e-01, 0.00000000e+00, 2.50263709e+00],
#        [4.05954533e+01, 9.90000000e+01, 2.00000000e+00, ...,
#         2.00000000e+00, 1.48863328e-01, 2.70227334e+00],
#        [1.90000000e+01, 5.30000000e+01, 3.00000000e+00, ...,
#         2.00000000e+00, 1.00000000e+00, 1.00000000e+00]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train, Y_train)
# Out:
# c:\Users\ashutosh pandey\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
Y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,r2_score

# %%
accuracy_score(Y_test, Y_pred)
# Out:
# 0.35964912280701755

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier(
    max_depth=10,
    min_samples_split=10,
    min_samples_leaf=5,
    random_state=42
)

# %%
dtc.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=5, min_samples_split=10,
#                        random_state=42)

# %%
Y_pred = dtc.predict(X_test)

# %%
accuracy_score(Y_pred, Y_test)
# Out:
# 0.6388888888888888

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [15, 20, 25],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

# %%
rfc = RandomForestClassifier(random_state=42)

# %%
grid = GridSearchCV(rfc, param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
grid.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[221], line 1
# ----> 1 grid.fit(X_train, Y_train)
#
# File c:\Users\ashutosh pandey\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\ashutosh pandey\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1019, in BaseSearchCV.fit(self, X, y, **params)
#    1013     results = self._format_results(
#    1014         all_candidate_params, n_splits, all_out, all_more_results
#    1015     )
#    1017     return results
# -> 1019 self._run_search(evaluate_candidates)
#    1021 # multimetric is determined here because in the case of a callable
#    1022 # self.scoring the return type is only known after calling
#    1023 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\ashutosh pandey\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1573, in GridSearchCV._run_search(self, evaluate_candidates)
#    1571 def _run_search(self, evaluate_candidates):
#    1572     """Search all candidates in param_grid"""
# -> 1573     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\ashutosh pandey\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:965, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     957 if self.verbose > 0:
#     958     print(
#     959         "Fitting {0} folds for each of {1} candidates,"
#     960         " totalling {2} fits".format(
#     961             n_splits, n_candidates, n_candidates * n_splits
#     962         )
#     963     )
# --> 965 out = parallel(
#     966     delayed(_fit_and_score)(
#     967         clone(base_estimator),
#     968         X,
#     969         y,
#     970         train=train,
#     971         test=test,
#     972         parameters=parameters,
#     973         split_progress=(split_idx, n_splits),
#     974         candidate_progress=(cand_idx, n_candidates),
#     975         **fit_and_score_kwargs,
#     976     )
#     977     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     978         enumerate(candidate_params),
#     979         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     980     )
#     981 )
#     983 if len(out) < 1:
#     984     raise ValueError(
#     985         "No fits were performed. "
#     986         "Was the CV iterator empty? "
#     987         "Were there no candidates?"
#     988     )
#
# File c:\Users\ashutosh pandey\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File c:\Users\ashutosh pandey\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File c:\Users\ashutosh pandey\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File c:\Users\ashutosh pandey\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
Y_pred2 = grid.predict(X_test)

# %%
accuracy_score(Y_pred2, Y_test)
# Out:
# 0.9632317368166424

# %%
grid.best_params_
# Out:
# {'max_depth': 25,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 300}

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %%
Y_pred3 = knn.predict(X_test)

# %%
accuracy_score(Y_pred3, Y_test)
# Out:
# 0.8746976294146106

# %%
X_test = pd.DataFrame(X_test)

# %%
X_test
# Out:
#               0          1         2          3         4         5         6  \
# 0     31.570555  73.809135  3.000000  12.809135  1.095432  1.952284  0.000000
# 1      6.990505  67.113938  3.000000   4.971515  2.000000  0.018990  1.000000
# 2     12.000000  33.000000  1.000000   7.000000  0.000000  2.000000  0.000000
# 3      5.514386  90.971228  3.000000   4.913683  1.028772  0.485614  0.485614
# 4     23.956396  66.869189  1.912792  25.825585  1.043604  1.956396  0.000000
# ...         ...        ...       ...        ...       ...       ...       ...
# 2062  25.631908  45.210115  3.000000   5.842023  1.157977  1.684046  0.000000
# 2063  19.486386  67.486386  1.504538  20.752269  1.504538  0.495462  1.000000
# 2064  28.576344  65.945806  3.000000   9.630538  2.315269  1.369462  1.000000
# 2065   7.983652  31.032697  1.989101  23.956404  2.994551  1.994551  0.000000
# 2066  10.546792  29.677564  3.000000  11.485901  0.644871  2.000000  0.000000
#
#              7
# 0     3.000000
# 1     0.000000
# 2     2.000000
# 3     1.971228
# 4     1.087208
# ...        ...
# 2062  0.000000
# 2063  1.247731
# 2064  1.000000
# 2065  0.994551
# 2066  3.000000
#
# [2067 rows x 8 columns]

# %%
Y_test = pd.DataFrame(Y_test)

# %%
Y_test.head(20)
# Out:
#      0
# 0   17
# 1   30
# 2   25
# 3   32
# 4   12
# 5   30
# 6   21
# 7   26
# 8   20
# 9   35
# 10  33
# 11  20
# 12  34
# 13   1
# 14  19
# 15  12
# 16  29
# 17   0
# 18  11
# 19  21

# %%
pred = dtc.predict(X_test.iloc[13, 0:8].values.reshape(1,-1))

# %%
pred
# Out:
# array([1])

# %%
pred2 = model.predict(X_test.iloc[13, 0:8].values.reshape(1,-1))

# %%
pred2
