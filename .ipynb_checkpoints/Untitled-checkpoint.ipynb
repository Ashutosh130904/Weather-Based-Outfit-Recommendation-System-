# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("weather_outfit_dataset_1500.csv")

# %%
df.head(20)
# Out:
#     Temperature  Humidity Weather  WindSpeed TimeOfDay LocationType  \
# 0            18        93   Sunny         24       Day        Urban
# 1            38        85   Windy         36       Day      Coastal
# 2            32        30   Rainy         11   Evening        Urban
# 3            11        66  Cloudy         33   Evening      Coastal
# 4            16        24   Windy          2       Day      Coastal
# 5            23        31   Snowy         36       Day     Mountain
# 6            30        90   Windy         30   Evening      Coastal
# 7             8        53  Cloudy          9       Day      Coastal
# 8            18        40  Cloudy          1     Night        Urban
# 9            22        94   Sunny          1     Night        Urban
# 10           29        87  Cloudy         33   Morning     Mountain
# 11           38        37   Sunny         15   Morning        Urban
# 12           39        79   Snowy          1     Night     Mountain
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Temperature   1100 non-null   int64
#  1   Humidity      1100 non-null   int64
#  2   Weather       1100 non-null   object
#  3   WindSpeed     1100 non-null   int64
#  4   TimeOfDay     1100 non-null   object
#  5   LocationType  1100 non-null   object
#  6   Outfit        1100 non-null   object
#  7   Gender        1100 non-null   object
#  8   AgeGroup      1100 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 77.5+ KB

# %%
df.describe()
# Out:
#        Temperature     Humidity    WindSpeed
# count  1100.000000  1100.000000  1100.000000
# mean     24.413636    58.947273    19.924545
# std      11.464500    23.694310    11.946679
# min       5.000000    20.000000     0.000000
# 25%      15.000000    38.000000    10.000000
# 50%      24.000000    58.000000    20.000000
# 75%      34.000000    80.000000    30.000000
# max      45.000000   100.000000    40.000000

# %%
print(df.isnull().sum())
# Out:
# Temperature     0
# Humidity        0
# Weather         0
# WindSpeed       0
# TimeOfDay       0
# LocationType    0
# Outfit          0
# Gender          0
# AgeGroup        0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis

# ========== 1. Correlation Heatmap ==========
plt.figure(figsize=(10, 6))
sns.heatmap(df[numerical_cols + categorical_cols].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# ========== 2. Boxplots for Outlier Detection ==========
for col in numerical_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(y=df[col], color='skyblue')
    plt.title(f'Boxplot of {col}')
    plt.tight_layout()
    plt.show()

# ========== 3. Histograms with Skewness and Kurtosis ==========
for col in numerical_cols:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], kde=True, color='salmon', bins=30)
    plt.title(f'{col} Distribution\nSkewness: {df[col].skew():.2f} | Kurtosis: {df[col].kurtosis():.2f}')
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       5 # ========== 1. Correlation Heatmap ==========
#       6 plt.figure(figsize=(10, 6))
# ----> 7 sns.heatmap(df[numerical_cols + categorical_cols].corr(), annot=True, cmap='coolwarm', fmt=".2f")
#       8 plt.title("Correlation Heatmap")
#       9 plt.tight_layout()
#
# NameError: name 'numerical_cols' is not defined

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder

# %%
le = LabelEncoder()
oe = OrdinalEncoder()

# %%
print(df['Outfit'])
# Out:
# 0           T-shirt
# 1           Sweater
# 2          Raincoat
# 3           Sweater
# 4           Sweater
#            ...
# 1095       Raincoat
# 1096    Winter Coat
# 1097    Winter Coat
# 1098         Jacket
# 1099         Jacket
# Name: Outfit, Length: 1100, dtype: object

# %%
df['Outfit'] = df['Outfit'].astype(str)
df['Outfit'] = le.fit_transform(df['Outfit'])

# %%
print(df['Outfit'])
# Out:
# 0       4
# 1       3
# 2       1
# 3       3
# 4       3
#        ..
# 1095    1
# 1096    5
# 1097    5
# 1098    0
# 1099    0
# Name: Outfit, Length: 1100, dtype: int64

# %%
df[['Weather']] = df[['Weather']].astype(str)
df[['Weather']] = oe.fit_transform(df[['Weather']])

# %%
print(df['Weather'].unique())
# Out:
# [3. 4. 1. 0. 2.]

# %%
df[['TimeOfDay']] = df[['TimeOfDay']].astype(str)
df[['TimeOfDay']] = oe.fit_transform(df[['TimeOfDay']])

# %%
print(df['TimeOfDay'])
# Out:
# 0       0.0
# 1       0.0
# 2       1.0
# 3       1.0
# 4       0.0
#        ...
# 1095    2.0
# 1096    0.0
# 1097    2.0
# 1098    3.0
# 1099    2.0
# Name: TimeOfDay, Length: 1100, dtype: float64

# %%
df[['LocationType']] = df[['LocationType']].astype(str)
df[['LocationType']] = oe.fit_transform(df[['LocationType']])

# %%
print(df['LocationType'])
# Out:
# 0       2.0
# 1       0.0
# 2       2.0
# 3       0.0
# 4       0.0
#        ...
# 1095    0.0
# 1096    1.0
# 1097    0.0
# 1098    0.0
# 1099    0.0
# Name: LocationType, Length: 1100, dtype: float64

# %%
df[['Gender']] = df[['Gender']].astype(str)
df[['Gender']] = oe.fit_transform(df[['Gender']])

# %%
print(df['Gender'])
# Out:
# 0       1.0
# 1       0.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 1095    0.0
# 1096    0.0
# 1097    0.0
# 1098    0.0
# 1099    1.0
# Name: Gender, Length: 1100, dtype: float64

# %%
df[['AgeGroup']] = df[['AgeGroup']].astype(str)
df[['AgeGroup']] = oe.fit_transform(df[['AgeGroup']])

# %%
print(df['AgeGroup'])
# Out:
# 0       0.0
# 1       3.0
# 2       2.0
# 3       1.0
# 4       3.0
#        ...
# 1095    3.0
# 1096    0.0
# 1097    2.0
# 1098    3.0
# 1099    1.0
# Name: AgeGroup, Length: 1100, dtype: float64

# %%
df.head(20)
# Out:
#     Temperature  Humidity  Weather  WindSpeed  TimeOfDay  LocationType  \
# 0            18        93      3.0         24        0.0           2.0
# 1            38        85      4.0         36        0.0           0.0
# 2            32        30      1.0         11        1.0           2.0
# 3            11        66      0.0         33        1.0           0.0
# 4            16        24      4.0          2        0.0           0.0
# 5            23        31      2.0         36        0.0           1.0
# 6            30        90      4.0         30        1.0           0.0
# 7             8        53      0.0          9        0.0           0.0
# 8            18        40      0.0          1        3.0           2.0
# 9            22        94      3.0          1        3.0           2.0
# 10           29        87      0.0         33        2.0           1.0
# 11           38        37      3.0         15        2.0           2.0
# ...

# %%
features = ["Temperature", "Humidity", "Weather", "WindSpeed", "TimeOfDay", "LocationType", "Gender", "AgeGroup"]

# %%
X = df[features].values
Y = df['Outfit'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
X_train
# Out:
# array([[28., 97.,  0., ...,  2.,  1.,  1.],
#        [38., 76.,  4., ...,  2.,  0.,  3.],
#        [30., 38.,  1., ...,  0.,  1.,  3.],
#        ...,
#        [12., 71.,  0., ...,  1.,  0.,  1.],
#        [12., 33.,  1., ...,  0.,  0.,  3.],
#        [40., 52.,  4., ...,  0.,  0.,  3.]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train, Y_train)
# Out:
# C:\Users\ashutosh pandey\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
Y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,r2_score

# %%
accuracy_score(Y_test, Y_pred)
# Out:
# 0.19545454545454546

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier(
    max_depth=10,
    min_samples_split=10,
    min_samples_leaf=5,
    random_state=42
)

# %%
dtc.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=5, min_samples_split=10,
#                        random_state=42)

# %%
Y_pred = dtc.predict(X_test)

# %%
accuracy_score(Y_pred, Y_test)
# Out:
# 0.7045454545454546

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

# %%
param_grid= {
    "n_estimators":[100,200,300,400,500],
    "max_depth":[10,20,30,None],
    "min_samples_split":[2,5,10],
    "min_samples_leaf":[1,2,4],
    "max_features":['sqrt','log2',None]
}

# %%
rfc = RandomForestClassifier(random_state=42)

# %%
model = RandomizedSearchCV(
    rfc,
    param_distributions=param_grid,
    n_iter=20,
    cv=10,
    scoring='accuracy',
    n_jobs=-1,
    verbose=1
)

# %%
model.fit(X_train, Y_train)
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# RandomizedSearchCV(cv=10, estimator=RandomForestClassifier(random_state=42),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'max_depth': [10, 20, 30, None],
#                                         'max_features': ['sqrt', 'log2', None],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500]},
#                    scoring='accuracy', verbose=1)

# %%
Y_pred2 = model.predict(X_test)

# %%
accuracy_score(Y_pred2, Y_test)
# Out:
# 0.6909090909090909

# %%
X_test = pd.DataFrame(X_test)

# %%
X_test
# Out:
#         0     1    2     3    4    5    6    7
# 0    32.0  99.0  3.0  13.0  3.0  1.0  0.0  3.0
# 1    24.0  78.0  4.0  23.0  3.0  1.0  1.0  1.0
# 2     7.0  41.0  2.0  26.0  1.0  1.0  1.0  1.0
# 3    28.0  28.0  3.0  26.0  0.0  0.0  0.0  0.0
# 4    20.0  54.0  2.0  34.0  1.0  2.0  1.0  0.0
# ..    ...   ...  ...   ...  ...  ...  ...  ...
# 215  29.0  21.0  3.0  37.0  3.0  0.0  0.0  1.0
# 216  43.0  61.0  2.0  11.0  1.0  2.0  0.0  2.0
# 217  37.0  96.0  3.0   0.0  3.0  0.0  0.0  2.0
# 218  22.0  78.0  1.0   7.0  3.0  2.0  0.0  1.0
# 219   6.0  70.0  3.0  21.0  2.0  1.0  1.0  1.0
#
# [220 rows x 8 columns]

# %%
Y_test = pd.DataFrame(Y_test)

# %%
Y_test.head(20)
# Out:
#     0
# 0   4
# 1   3
# 2   5
# 3   2
# 4   5
# 5   1
# 6   0
# 7   0
# 8   5
# 9   1
# 10  1
# 11  1
# 12  3
# 13  1
# 14  0
# 15  0
# 16  4
# 17  1
# 18  4
# 19  3

# %%
pred = dtc.predict(X_test.iloc[13, 0:8].values.reshape(1,-1))

# %%
pred
# Out:
# array([1])

# %%
pred2 = model.predict(X_test.iloc[13, 0:8].values.reshape(1,-1))

# %%
pred2
# Out:
# array([1])

# %%
# !pip install imbalanced-learn
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier, StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE

# Load dataset
df = pd.read_csv("weather_outfit_dataset_1100_modified.csv")

# Encode target variable
le = LabelEncoder()
df['Outfit'] = le.fit_transform(df['Outfit'].astype(str))

# One-hot encode categorical features
categorical_cols = ['Weather', 'TimeOfDay', 'LocationType', 'Gender', 'AgeGroup']
df = pd.get_dummies(df, columns=categorical_cols)

# Features and Target
X = df.drop('Outfit', axis=1)
Y = df['Outfit']

# Handle class imbalance
sm = SMOTE(random_state=42)
X_res, Y_res = sm.fit_resample(X, Y)

# Train-Test Split
X_train, X_test, Y_train, Y_test = train_test_split(X_res, Y_res, test_size=0.2, random_state=42, stratify=Y_res)

# Base Models
rf = RandomForestClassifier(n_estimators=200, max_depth=20, random_state=42)
dt = DecisionTreeClassifier(max_depth=10, min_samples_split=10, min_samples_leaf=5, random_state=42)
lr = LogisticRegression(max_iter=1000)
xgb = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)

# Stacking Ensemble
estimators = [('rf', rf), ('dt', dt), ('xgb', xgb)]
stack = StackingClassifier(estimators=estimators, final_estimator=lr, cv=5)
stack.fit(X_train, Y_train)

# Prediction and Evaluation
Y_pred = stack.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print(f"Stacked Model Accuracy: {accuracy:.4f}")

# Cross-validation Accuracy
cv = StratifiedKFold(n_splits=10)
scores = cross_val_score(stack, X_res, Y_res, cv=cv, scoring='accuracy')
print("Cross-validated Accuracy:", scores.mean())
# Out:
# C:\Users\ashutosh pandey\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:08:18] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\ashutosh pandey\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:08:24] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\ashutosh pandey\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:08:25] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ...
